# %%
df=pd.read_excel('counts na dropped1.xlsx')

# %%
df
# Out:
#               SYMBOL   ENTREZID  F_IgE_S3  F_unstim_S4  M_IgE_S1  M_unstim_S2  \
# 0              Gnai3      14679      7469         6485      5562         5949
# 1              Cdc45      12544        92          303       141          323
# 2                H19      14955         0            0         0            0
# 3               Apoh      11818         2            4         4            0
# 4               Narf      67608       853         1280       630          744
# ...              ...        ...       ...          ...       ...          ...
# 16317  4930412F12Rik      74849        18           28         8            2
# 16318  1600027J07Rik      69794         0            0         0            0
# 16319  A030001D20Rik  100126243         2            2         0            0
# 16320         Rnf223  100045778         0            5         0            0
# 16321  1700012D14Rik      75479        31           57        20           14
#
# ...

# %%
df1=df.loc[(abs(df['1MFi'] - df['2MFi']) < 0.05) & (abs(df['1MFu'] - df['2MFu']) < 0.05) & (df['2MFu'] != 0.0 )]

# %%
df1.to_excel('210310 common patterns in rnaseq.xlsx', index=False)
